# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
fullpath = "/Users/zZzer/Downloads/archive/exoplanets.csv"

# %%
data = pd.read_csv(fullpath)

# %%
data.head()
# Out:
#                  Name Mass (MJ) Radius (RJ) Period (days)  \
# 0         16 Cygni Bb      2.38         NaN         799.5
# 1         23 Librae b      1.61         NaN        258.18
# 2  47 Ursae Majoris b      2.53         NaN          1078
# 3         51 Pegasi b      0.46         NaN      4.230785
# 4         55 Cancri b    0.8306         NaN      14.65152
#
#   Semi-major axis (AU) Temp. (K) Discovery method  Disc. Year Distance (ly)  \
# 0                 1.66       NaN      radial vel.      1996.0         68.99
# 1                 0.81       NaN      radial vel.      1999.0         85.46
# 2                  2.1       NaN      radial vel.      1996.0         45.02
# 3               0.0527       NaN      radial vel.      1995.0         50.45
# 4             0.115227       700      radial vel.      1996.0         41.06
#
#   Host star mass (M☉) Host star temp. (K)  \
# 0                1.04                5750
# 1                1.07                5736
# ...

# %%
data.shape
# Out:
# (4855, 12)

# %%
data.columns
# Out:
# Index(['Name', 'Mass (MJ)', 'Radius (RJ)', 'Period (days)',
#        'Semi-major axis (AU)', 'Temp. (K)', 'Discovery method', 'Disc. Year',
#        'Distance (ly)', 'Host star mass (M☉)', 'Host star temp. (K)',
#        'Remarks'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Name', 'Mass (MJ)', 'Radius (RJ)', 'Period (days)',
#        'Semi-major axis (AU)', 'Temp. (K)', 'Discovery method', 'Disc. Year',
#        'Distance (ly)', 'Host star mass (M☉)', 'Host star temp. (K)',
#        'Remarks'],
#       dtype='object')

# %%
data.columns.values.tolist()
# Out:
# ['Name',
#  'Mass (MJ)',
#  'Radius (RJ)',
#  'Period (days)',
#  'Semi-major axis (AU)',
#  'Temp. (K)',
#  'Discovery method',
#  'Disc. Year',
#  'Distance (ly)',
#  'Host star mass (M☉)',
#  'Host star temp. (K)',
#  'Remarks']

# %%
data.describe()
# Out:
#         Disc. Year
# count   411.000000
# mean   2005.313869
# std       3.639389
# min    1988.000000
# 25%    2003.000000
# 50%    2006.000000
# 75%    2008.000000
# max    2009.000000

# %%
data["Name"][180]
# Out:
# 'HD 45364 b'

# %%
data.dtypes
# Out:
# Name                     object
# Mass (MJ)                object
# Radius (RJ)              object
# Period (days)            object
# Semi-major axis (AU)     object
# Temp. (K)                object
# Discovery method         object
# Disc. Year              float64
# Distance (ly)            object
# Host star mass (M☉)      object
# Host star temp. (K)      object
# Remarks                  object
# dtype: object

# %%
pd.isnull(data["Name"])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4850    False
# 4851    False
# 4852    False
# 4853    False
# 4854    False
# Name: Name, Length: 4855, dtype: bool

# %%
pd.isnull(data["Name"]).values.sum()
# Out:
# 0

# %%
data["Name"][97]
# Out:
# 'Gliese 581 c'

# %%
data.at[95, "Name"] = None

# %%
data["Name"][97]
# Out:
# 'Gliese 581 c'

# %%
pd.isnull(data["Name"]).values.sum()
# Out:
# 1

# %%
data.dropna(axis=0, how="all")
# Out:
#                     Name                Mass (MJ)           Radius (RJ)  \
# 0            16 Cygni Bb                     2.38                   NaN
# 1            23 Librae b                     1.61                   NaN
# 2     47 Ursae Majoris b                     2.53                   NaN
# 3            51 Pegasi b                     0.46                   NaN
# 4            55 Cancri b                   0.8306                   NaN
# ...                  ...                      ...                   ...
# 4850         BD-210397 b                  0.7±0.1                   NaN
# 4851         BD-210397 c              2.4+1.5−0.7                   NaN
# 4852    EPIC 229004835 b     0.0327+0.0050−0.0047  0.2080+0.0071−0.0084
# 4853           GJ 1151 c  0.03341+0.00412−0.00463                   NaN
# 4854            GJ 328 c     0.0673+0.0107−0.0101                   NaN
#
#            Period (days)  Semi-major axis (AU) Temp. (K) Discovery method  \
# ...

# %%
data.dropna(axis=0, how = "any")
# Out:
#               Name Mass (MJ) Radius (RJ) Period (days) Semi-major axis (AU)  \
# 18     HD 209458 b      0.73        1.39    3.52474859              0.04707
# 53     55 Cancri e   0.02542        0.17      0.736539              0.01544
# 108  Gliese 1214 b    0.0197       0.254    1.58040456              0.01411
# 112       HAT-P-2b       8.7       0.951     5.6335158              0.06814
# 113       HAT-P-3b      0.65        0.94        2.8997              0.03866
# 115       HAT-P-5b      0.98        1.21       2.78849              0.04073
# 116       HAT-P-6b      1.32        1.48       3.85298              0.05239
# 117       HAT-P-7b      1.84        1.51       2.20474              0.03676
# 119       HAT-P-9b     0.749       1.393    3.92281072              0.05287
# 120      HAT-P-11b     0.084       0.389    4.88780244              0.05254
# 150     HD 17156 b      3.51         1.1      21.21663              0.16278
# ...

# %%
data_collnan = data.dropna(axis = 1, how = "any")

# %%
del data_collnan

# %%
data
# Out:
#                     Name                Mass (MJ)           Radius (RJ)  \
# 0            16 Cygni Bb                     2.38                   NaN
# 1            23 Librae b                     1.61                   NaN
# 2     47 Ursae Majoris b                     2.53                   NaN
# 3            51 Pegasi b                     0.46                   NaN
# 4            55 Cancri b                   0.8306                   NaN
# ...                  ...                      ...                   ...
# 4850         BD-210397 b                  0.7±0.1                   NaN
# 4851         BD-210397 c              2.4+1.5−0.7                   NaN
# 4852    EPIC 229004835 b     0.0327+0.0050−0.0047  0.2080+0.0071−0.0084
# 4853           GJ 1151 c  0.03341+0.00412−0.00463                   NaN
# 4854            GJ 328 c     0.0673+0.0107−0.0101                   NaN
#
#            Period (days)  Semi-major axis (AU) Temp. (K) Discovery method  \
# ...

# %%
data.fillna('X')
# Out:
#                     Name                Mass (MJ)           Radius (RJ)  \
# 0            16 Cygni Bb                     2.38                     X
# 1            23 Librae b                     1.61                     X
# 2     47 Ursae Majoris b                     2.53                     X
# 3            51 Pegasi b                     0.46                     X
# 4            55 Cancri b                   0.8306                     X
# ...                  ...                      ...                   ...
# 4850         BD-210397 b                  0.7±0.1                     X
# 4851         BD-210397 c              2.4+1.5−0.7                     X
# 4852    EPIC 229004835 b     0.0327+0.0050−0.0047  0.2080+0.0071−0.0084
# 4853           GJ 1151 c  0.03341+0.00412−0.00463                     X
# 4854            GJ 328 c     0.0673+0.0107−0.0101                     X
#
#            Period (days)  Semi-major axis (AU) Temp. (K) Discovery method  \
# ...

# %%
data1 = data
data1['Remarks'] = data1['Remarks'].fillna('X')

# %%
data1
# Out:
#                     Name                Mass (MJ)           Radius (RJ)  \
# 0            16 Cygni Bb                     2.38                   NaN
# 1            23 Librae b                     1.61                   NaN
# 2     47 Ursae Majoris b                     2.53                   NaN
# 3            51 Pegasi b                     0.46                   NaN
# 4            55 Cancri b                   0.8306                   NaN
# ...                  ...                      ...                   ...
# 4850         BD-210397 b                  0.7±0.1                   NaN
# 4851         BD-210397 c              2.4+1.5−0.7                   NaN
# 4852    EPIC 229004835 b     0.0327+0.0050−0.0047  0.2080+0.0071−0.0084
# 4853           GJ 1151 c  0.03341+0.00412−0.00463                   NaN
# 4854            GJ 328 c     0.0673+0.0107−0.0101                   NaN
#
#            Period (days)  Semi-major axis (AU) Temp. (K) Discovery method  \
# ...

# %%
print(data1['Host star temp. (K)'].dtype)
# Out:
# object

# %%
data1['Host star temp. (K)'] = pd.to_numeric(data1['Host star temp. (K)'], errors='coerce')

# %%
data1['Host star temp. (K)'] = data1['Host star temp. (K)'].fillna(data1['Host star temp. (K)'].mean())

# %%
data1
# Out:
#                     Name                Mass (MJ)           Radius (RJ)  \
# 0            16 Cygni Bb                     2.38                   NaN
# 1            23 Librae b                     1.61                   NaN
# 2     47 Ursae Majoris b                     2.53                   NaN
# 3            51 Pegasi b                     0.46                   NaN
# 4            55 Cancri b                   0.8306                   NaN
# ...                  ...                      ...                   ...
# 4850         BD-210397 b                  0.7±0.1                   NaN
# 4851         BD-210397 c              2.4+1.5−0.7                   NaN
# 4852    EPIC 229004835 b     0.0327+0.0050−0.0047  0.2080+0.0071−0.0084
# 4853           GJ 1151 c  0.03341+0.00412−0.00463                   NaN
# 4854            GJ 328 c     0.0673+0.0107−0.0101                   NaN
#
#            Period (days)  Semi-major axis (AU) Temp. (K) Discovery method  \
# ...

# %%
data2 = pd.read_csv(fullpath)
data2=["Host star temp. (K)"]

# %%
plt.hist(data1['Period (days)'].dropna(), bins=20)  
plt.xlabel('Periodo (días)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Periodo de Exoplanetas')
plt.show()
